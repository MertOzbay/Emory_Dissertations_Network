# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
thesis_df = pd.read_csv('theses_v2.csv')
thesis_df
# Out:
#       Unnamed: 0                                              title  \
# 0              0          Does Inflammation Damage White Matter ...
# 1              1     Chlorhexidine bigluconate resistance in Met...
# 2              2     IRF4 controls cell fate outcomes during the...
# 3              3    From Surviving to Thriving:  Exploring Healt...
# 4              4    Maternal Exposures to Cigarette Smoking and ...
# ...          ...                                                ...
# 9976        9976  Zimbabwe's Maturing HIV Epidemic: A Triangulat...
# 9977        9977  Zooarchaeological Faunal Identifiability: Usin...
# 9978        9978  Zoomorphic Others: The Animalization of Stigma...
# 9979        9979  Zoonotic Diseases in Refugee or Internally Dis...
# 9980        9980  Zoonotic Transmission Dynamics of Hemorrhagic ...
#
#                                school                           department  \
# ...

# %%
thesis_df['department'].value_counts()
# Out:
# Epidemiology                                        1412
# Global Health                                       1050
# Biological and Biomedical Sciences                   961
# Chemistry                                            455
# Psychology                                           440
# Public Health                                        353
# Environmental Health                                 349
# Biostatistics and Bioinformatics                     335
# Behavioral Sciences and Health Education             314
# Biology                                              292
# Religion                                             275
# English and Creative Writing                         269
# Neuroscience and Behavioral Biology                  238
# History                                              216
# Clinical Research                                    198
# Political Science                                    175
# ...

# %%
pd.options.display.max_rows = 100

# %%
counts, bins = np.histogram(list(thesis_df['department'].value_counts()))

# %%
plt.hist(bins[:-1], bins, weights=counts)
# Out:
# (array([94., 11.,  3.,  2.,  0.,  0.,  1.,  1.,  0.,  1.]),
#  array([1.0000e+00, 1.4170e+02, 2.8240e+02, 4.2310e+02, 5.6380e+02,
#         7.0450e+02, 8.4520e+02, 9.8590e+02, 1.1266e+03, 1.2673e+03,
#         1.4080e+03]),
#  <BarContainer object of 10 artists>)

# %%
plt.bar(list(thesis_df['department'].value_counts()), height=5)
# Out:
# <BarContainer object of 113 artists>

# %%
thesis_df_raw = pd.read_csv('theses.csv')

# %%
thesis_df_raw['department'].unique()
# Out:
# array(['Neuroscience and Behavioral Biology', 'Epidemiology',
#        'Biological and Biomedical Sciences', 'Ministry',
#        'Hubert Department of Global Health', 'Chemistry', 'Divinity',
#        'Behavioral Sciences and Health Education', 'Human Health',
#        'Executive Masters of Public Health - MPH', 'Clinical Research',
#        'Comparative Literature', 'Environmental Health', 'Biostatistics',
#        'Psychology', 'Anthropology', 'American Studies',
#        'Computer Science and Informatics', 'Mathematics',
#        'Middle Eastern and South Asian Studies',
#        'Graduate Institute of the Liberal Arts', 'Political Science',
#        'Linguistics', 'Art History', 'Educational Studies', nan,
#        'Religion', 'Philosophy', 'History', "Women's Studies", 'Classics',
#        'Latin American and Caribbean Studies', 'French', 'English',
#        'Spanish', 'English and History', 'Bioethics',
#        "Women's, Gender, and Sexuality Studies", 'Journalism',
# ...
